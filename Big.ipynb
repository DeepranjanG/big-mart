# %% [markdown]
# 1]Data Collection ---- load,summary statistics,information about dataset
#
# 2]Data cleansing --- missing values removal
#
# 3]EDA----visualization , outlier removal
#
# 4]Data pre-processing----Encoding , Correlation matrix
#
# 5]Creation of train test and validation sets -----Divide the data into train and test split
#
# 6]Model Creation-----Use regression models
#
# 7]Hyperparameter tuning --- Grid Search Cv or randomized search cv
#
# 8]Model deployment ----using pickle library to save the best model.

# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
import warnings
warnings.filterwarnings("ignore")

# %%
# Loading DataSet
df = pd.read_csv('Train.csv')

# %%
# Printing the head of the DataSet
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Printing the Unique Data present in the DataSet features(columns)

print("Unique Data in Item_Identifier")
print("                              ")
print(df["Item_Identifier"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_Weight")
print("                              ")
print(df["Item_Weight"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_Fat_Content")
print("                              ")
print(df["Item_Fat_Content"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_Visibility")
print("                              ")
print(df["Item_Visibility"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_Type")
print("                              ")
print(df["Item_Type"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_MRP")
print("                              ")
print(df["Item_MRP"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Outlet_Identifier")
print("                              ")
print(df["Outlet_Identifier"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Outlet_Establishment_Year")
print("                              ")
print(df["Outlet_Establishment_Year"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Outlet_Size")
print("                              ")
print(df["Outlet_Size"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Outlet_Location_Type")
print("                              ")
print(df["Outlet_Location_Type"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Outlet_Type")
print("                              ")
print(df["Outlet_Type"].unique())

print("------------------------------")
print("                              ")


print("Unique Data in Item_Outlet_Sales")
print("                              ")
print(df["Item_Outlet_Sales"].unique())

print("------------------------------")
# Out:
# Unique Data in Item_Identifier
#
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# ------------------------------
#
# Unique Data in Item_Weight
#
# [ 9.3    5.92  17.5   19.2    8.93  10.395 13.65     nan 16.2   11.8
#  18.5   15.1   17.6   16.35   9.    13.35  18.85  14.6   13.85  13.
#   7.645 11.65   5.925 19.25  18.6   18.7   17.85  10.     8.85   9.8
#  13.6   21.35  12.15   6.42  19.6   15.85   7.39  10.195  9.895 10.895
#   7.905  9.195  8.365  7.97  17.7   19.35   8.645 15.6   18.25   7.855
#   7.825  8.39  12.85  19.     5.905  7.76  16.75  15.5    6.055  6.305
#  20.85  20.75   8.895 19.7    8.75  13.3    8.31  19.75  17.1   10.5
#   6.635 14.15   8.89   9.1    7.5   16.85   7.485 11.6   12.65  20.25
#   8.6   12.6    8.88  20.5   13.5    7.235  6.92   8.02  12.8   16.6
#  14.    16.    21.25   7.365 18.35   5.465  7.27   6.155 19.5   15.2
#  14.5   13.1   12.3   11.1   11.3    5.75  11.35   6.525 10.3    5.78
# ...

# %%
print("Unique Data in Item_Identifier")
print("                              ")
print(df["Item_Identifier"].unique())

print("------------------------------")
# Out:
# Unique Data in Item_Identifier
#
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# ------------------------------

# %%
# Description of the dataset
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Columns Present in the dataset
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Shape of the dataset
df.shape
# Out:
# (8523, 12)

# %%
df["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
# Target Variable is Item_Outlet_Sales

df.Item_Outlet_Sales.value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
# Datatye of the target variable
df.Item_Outlet_Sales.dtypes
# Out:
# dtype('float64')

# %%
df["Item_Outlet_Sales"].dtypes
# Out:
# dtype('float64')

# %%
categorical = df.select_dtypes(include =[np.object])
print("Categorical Features in Data Set:",categorical.shape[1])
# Out:
# Categorical Features in Data Set: 7

# %%
numerical= df.select_dtypes(include =[np.float64,np.int64])
print("Numerical Features in Data Set:",numerical.shape[1])
# Out:
# Numerical Features in Data Set: 5

# %%
# Printing the heat Plot
plt.figure(figsize=(15,12))
sns.heatmap(df.describe().T,annot=True,linecolor='white',linewidths=4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Why missing values treatment is required?
#
# Missing data in the training data set can reduce the power / fit of a model or can lead to a biased model . It can lead to wrong prediction.

# %%
# Checking the null values in the dataset

df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.boxplot('Item_Weight',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %%
# Filling the numerical data with its mean values
df['Item_Weight']= df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Filling the categorical data with its mode values
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Visualization

# %% [markdown]
# Bar - Plot

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
df['Item_Fat_Content'].replace(['low fat','LF','reg'],['Low Fat','Low Fat','Regular'],inplace = True)

# %%
df['Years_Established'] = df['Outlet_Establishment_Year'].apply(lambda x: 2020 - x)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_Identifier'],df['Item_Outlet_Sales'])
plt.title('Item_Identifier vs Item_Outlet_Sales')
plt.xlabel('Item_Identifier')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_Weight'],df['Item_Outlet_Sales'])
plt.title('Item_Weight vs Item_Outlet_Sales')
plt.xlabel('Item_Weight')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_Fat_Content'],df['Item_Outlet_Sales'])
plt.title('Item_Fat_Content vs Item_Outlet_Sales')
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_Visibility'],df['Item_Outlet_Sales'])
plt.title('Item_Visibility vs Item_Outlet_Sales')
plt.xlabel('Item_Visibility')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_Type'],df['Item_Outlet_Sales'])
plt.title('Item_Type vs Item_Outlet_Sales')
plt.xlabel('Item_Type')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Item_MRP'],df['Item_Outlet_Sales'])
plt.title('Item_MRP vs Item_Outlet_Sales')
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Outlet_Identifier'],df['Item_Outlet_Sales'])
plt.title('Outlet_Identifier vs Item_Outlet_Sales')
plt.xlabel('Outlet_Identifier')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Outlet_Establishment_Year'],df['Item_Outlet_Sales'])
plt.title('Outlet_Establishment_Year vs Item_Outlet_Sales')
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(df['Outlet_Size'],df['Item_Outlet_Sales'])
plt.title('Outlet_Size vs Item_Outlet_Sales')
plt.xlabel('Outlet_Size')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %% [markdown]
# Histogram
#
# Note : Histogram is always plot numerical data

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Years_Established'],
#       dtype='object')

# %%
df.Item_Weight.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64>

# %%
#Data Is numerical then also it is not getting printed
#plt.figure(figsize=(10,7))
#df.hist(column='Item_Weight',grid=False,edgecolor='black')

# %%
plt.figure(figsize=(10,7))
df.hist(column='Item_Visibility',grid=False,edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'Item_Visibility'}>]], dtype=object)

# %%
df.Item_Visibility.value_counts()
# Out:
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64

# %%
plt.figure(figsize=(10,7))
df.hist(column='Item_MRP',grid=False,edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'Item_MRP'}>]], dtype=object)

# %%
plt.figure(figsize=(10,7))
df.hist(column='Outlet_Establishment_Year',grid=False,edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'Outlet_Establishment_Year'}>]],
#       dtype=object)

# %%
plt.figure(figsize=(10,7))
df.hist(column='Item_Outlet_Sales',grid=False,edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'Item_Outlet_Sales'}>]], dtype=object)

# %% [markdown]
# line - plot

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Years_Established'],
#       dtype='object')

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_Identifier", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_Weight", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_Fat_Content", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_Visibility", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_Type", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Item_MRP", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Outlet_Identifier", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Outlet_Establishment_Year", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Outlet_Size", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Outlet_Location_Type", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize = (10, 8))
sns.lineplot(data=df, x="Outlet_Type", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# dist - plot
#
# Note : distance plot is always used to plot  numerical data

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Years_Established'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['Item_Weight'],color='blue')
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['Item_Visibility'],color='blue')
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['Item_MRP'],color='blue')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['Outlet_Establishment_Year'],color='blue')
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['Item_Outlet_Sales'],color='blue')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# Count - Plot

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Years_Established'],
#       dtype='object')

# %%
sns.countplot(x = 'Item_Identifier', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='count'>

# %%
sns.countplot(x = 'Item_Weight', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='count'>

# %%
sns.countplot(x = 'Item_Fat_Content', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.countplot(x = 'Item_Visibility', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='count'>

# %%
sns.countplot(x = 'Item_Type', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
sns.countplot(x = 'Item_MRP', data = df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Identifier', data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Establishment_Year', data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Size', data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Location_Type', data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(x = 'Outlet_Type', data = df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
sns.countplot(x = 'Item_Outlet_Sales', data = df)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='count'>

# %% [markdown]
# Box - Plot
#
# Note : Box plot is always used to plot  numerical data

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Dont Know y it is not printing need to check
# sns.boxplot(x=df["Item_Weight"])

# %%
sns.boxplot(x=df["Item_Visibility"])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %% [markdown]
# Note : Here we can see that in Item_Visibility there are  outliers we have to remove it

# %%
sns.boxplot(x=df["Item_MRP"])
# Out:
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.boxplot(x=df["Outlet_Establishment_Year"])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.boxplot(x=df["Item_Outlet_Sales"])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %% [markdown]
# Note : Here we can see that in Item_Outlet_Sales there are  outliers we have to remove it

# %%
# Removing the Outliers
q1 = df['Item_Visibility'].quantile(0.25)
q3 = df['Item_Visibility'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 0.067595815

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1- 1.5 * iqr

# %%
upper_limit
# Out:
# 0.195979015

# %%
lower_limit
# Out:
# -0.07440424500000001

# %%
sns.boxplot(x = df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
# Removing the Outliers
Q1 = df['Item_Outlet_Sales'].quantile(0.25)
Q3 = df['Item_Outlet_Sales'].quantile(0.75)

# %%
Q1
# Out:
# 834.2474

# %%
Q3
# Out:
# 3101.2964

# %%
ul = Q3 + 1.5 * iqr
ll = Q1- 1.5 * iqr

# %%
ul
# Out:
# 3101.3977937225

# %%
ll
# Out:
# 834.1460062775

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Note : Univariate statistics summarize only one variable at a time

# %%
plt.figure(figsize=(8,5))
sns.countplot('Item_Fat_Content',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# Note : The Items bought are more of Low Fat.

# %%
plt.figure(figsize=(25,7))
sns.countplot('Item_Type',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %% [markdown]
# Note :
# 1) Fruits and vegitables are highly sold and Snacks
#
# 2) Foods have also very good sales

# %%
plt.figure(figsize=(8,5))
sns.countplot('Outlet_Size',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %% [markdown]
# Note : The Outlets are more of Medium Size

# %%
plt.figure(figsize=(8,5))
sns.countplot('Outlet_Location_Type',data=df,palette='summer')
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %% [markdown]
# Note : Outlet location in tier 3 are more as compare to tire 1 and 2

# %%
plt.figure(figsize=(8,5))
sns.countplot('Outlet_Type',data=df,palette='twilight')
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %% [markdown]
# Note : Supermart Type1 has more outlet as compare to other

# %%
plt.figure(figsize=(8,5))
sns.countplot('Years_Established',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='Years_Established', ylabel='count'>

# %% [markdown]
# Note : Outlets counts are more and running from 35 years

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# Note : Bivariate statistics compare two variables

# %%
plt.figure(figsize=(8,5))
sns.barplot('Item_Fat_Content','Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Note : The Item Outles sales are high for both Low Fat and Regular Item types.

# %%
plt.figure(figsize=(8,5))
plt.scatter('Item_Visibility','Item_Outlet_Sales',data=df)

# %% [markdown]
# Note : Item_Visibility has a minimum value of zero. This makes no practical sense because when a product is being sold in a store, the visibility cannot be 0.

# %%
df['Item_Visibility']=df['Item_Visibility'].replace(0,df['Item_Visibility'].mean())

# %%
plt.figure(figsize=(8,5))
plt.scatter(y='Item_Visibility',x='Item_Outlet_Sales',data=df)
plt.xlabel('Item Outlet Sales')
plt.ylabel('Item Visibility')
# Out:
# Text(0, 0.5, 'Item Visibility')

# %% [markdown]
# Note : We can see that now visibility is not exactly zero and it has some value indicating that Item is rarely purchased by the customers.¶

# %%
plt.figure(figsize=(10,8))
sns.barplot(y='Item_Type',x='Item_Outlet_Sales',data=df,palette='spring')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_Type'>

# %% [markdown]
# Note : The products available were Dairy, Fruits - Vegetables and Snack Foods but the sales of Seafood and Starchy Foods seems higher and hence the sales can be improved with having stock of products that are most bought by customers.

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='Item_MRP', y='Item_Outlet_Sales',data=df)
plt.xlabel('Item MRP')
plt.ylabel('Item Outlet Sales')
# Out:
# Text(0, 0.5, 'Item Outlet Sales')

# %% [markdown]
# Note : Products who's MRP is more its has more sales we can see MRP 200 to 250 has more Sales

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Outlet_Size',y='Item_Outlet_Sales',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Note : Here outlet Medium and High size have more sales as compare to small outlet size

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=df,palette='plasma')
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Note : Here in Tire 2 and tire 3 have more sales as compare to tire 1 but tire 2 has more sales  then tire 3

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Years_Established',y='Item_Outlet_Sales',data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='Years_Established', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Note : Here we can see that the sales of the out let which is established 35 years ago has more sales as compare to other years
#     and the outlet which is established 22 years age have very less sales

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# Note : Multivariate statistics compare more than two variables.

# %%
plt.figure(figsize=(25,5))
sns.barplot('Item_Type','Item_Outlet_Sales',hue='Item_Fat_Content',data=df,palette='mako')
plt.legend()

# %% [markdown]
# Note :
# Item which are sold high with the low fat are : 1.) Breakfast, 2.) Snack Foods, 3.) Starchy Foods, 4.) Hard Drinks, 5.) Health and Hygiene
#
# Item which are sold high which are regular : 1.) Seafood, 2.) Fruits and Vegetables, 3.) Dairy.

# %%
plt.figure(figsize=(10,5))
sns.barplot('Outlet_Location_Type','Item_Outlet_Sales',hue='Outlet_Type',data=df,palette='magma')
plt.legend()

# %% [markdown]
# Note : Here we can see that the Supermarket tire 3 has more outlet sales as compare to other tires

# %%
iqr = q3-q1

# %%
iqr
# Out:
# -0.061499949

# %%
sns.boxplot(x=df["Item_Visibility"])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
df['Item_Outlet_Sales'].quantile(0.10)
# Out:
# 343.5528

# %% [markdown]
# # Data Pre - Processiong

# %% [markdown]
# Distributing the Categorical from the data set

# %%
cat_var = df.select_dtypes(include=['O'])
cat_var
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %% [markdown]
# Note : here we can cee that the Item weight is having numerical data but it is showing that it is in obj from so by using typecasting we have to convert from obj to numeric

# %%
df = df.astype({"Item_Weight":'float'})

# %%
# Printing all the categorical data

cat_var = df.select_dtypes(include=['O'])
cat_var
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %% [markdown]
# Label Encoding

# %%
# Converting the Categorical Data into Numerical

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
feature_var = ['Item_Fat_Content','Outlet_Location_Type','Outlet_Size','Outlet_Type','Item_Type']

for i in feature_var:
    df[i] = le.fit_transform(df[i])

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content               int32
# Item_Visibility              float64
# Item_Type                      int32
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                    int32
# Item_Outlet_Sales            float64
# Years_Established              int64
# dtype: object

# %% [markdown]
# Note : We need to Drop some Columns that are need to be droped and which are not nedd to be used any more in future

# %%
df = df.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year'],axis=1)

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.066132          6  182.0950
# 4         8.93                 0         0.066132          9   53.8614
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# 0            1                     0            1          3735.1380
# 1            1                     2            2           443.4228
# 2            1                     0            1          2097.2700
# 3            1                     2            0           732.3800
# 4            0                     2            1           994.7052
#
#    Years_Established
# 0                 21
# 1                 11
# 2                 21
# 3                 22
# ...

# %%
df.size
# Out:
# 85230

# %% [markdown]
# Spliting the Dependent and Independent Columns of the Data-Set
#
# X = Dependent Variable
#
# y = Independent Variable

# %%
# Printing all the Independent Variables(Features or Columns)
X = df.iloc[:, :-1]

# %%
X
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 0         0.016047          4  249.8092
# 1           5.920                 1         0.019278         14   48.2692
# 2          17.500                 0         0.016760         10  141.6180
# 3          19.200                 1         0.066132          6  182.0950
# 4           8.930                 0         0.066132          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 0         0.056783         13  214.5218
# 8519        8.380                 1         0.046982          0  108.1570
# 8520       10.600                 0         0.035186          8   85.1224
# 8521        7.210                 1         0.145221         13  103.1332
# 8522       14.800                 0         0.044878         14   75.4670
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
# Printing the Dependent Variable (Features or Columns)
y = df.iloc[:,9 ]

# %%
y
# Out:
# 0       21
# 1       11
# 2       21
# 3       22
# 4       33
#         ..
# 8518    33
# 8519    18
# 8520    16
# 8521    11
# 8522    23
# Name: Years_Established, Length: 8523, dtype: int64

# %%
X.shape
# Out:
# (8523, 9)

# %%
y.shape
# Out:
# (8523,)

# %% [markdown]
# Performing Standard Scalar
#
# Note : Standard Scalar is used to Convert the Unit data into unitless data

# %%
# Applying Standard Scalar

from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)
X_scaled
# Out:
# array([[-0.84187169, -0.73814723, -1.11135787, ..., -1.36933384,
#         -0.25265831,  0.910601  ],
#        [-1.64170589,  1.35474328, -1.04506727, ...,  1.09156913,
#          1.00297245, -1.01844035],
#        [ 1.09855449, -0.73814723, -1.09673346, ..., -1.36933384,
#         -0.25265831, -0.04923754],
#        ...,
#        [-0.53424315, -0.73814723, -0.71867224, ..., -0.13888236,
#         -0.25265831, -0.57909963],
#        [-1.33644372,  1.35474328,  1.53896846, ...,  1.09156913,
#          1.00297245, -0.19672492],
#        [ 0.45963367, -0.73814723, -0.51981553, ..., -1.36933384,
#         -0.25265831, -0.82959407]])

# %%
X_scaled.shape
# Out:
# (8523, 9)

# %%
y.shape
# Out:
# (8523,)

# %% [markdown]
# # Model - Building

# %% [markdown]
# We are building the regression algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.30, random_state=i)      # Creating train test split

# %% [markdown]
# ### Linear - Regression

# %% [markdown]
#  Note : linear regression is a regression model that estimates the relationship between one independent variable and one dependent variable using a straight line

# %%
r2score_maxAccuracy=0
maxRandomState=0

for i in range(1, 200):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.30, random_state=i)      # Creating train test split
    lr = LinearRegression(normalize=True)    # Creating Object of the Linear Regressor
    lr.fit(X_train, y_train)        # Fitting the x and y train data
    y_lr = lr.predict(X_test)       # predicting the x_test data and storing it into y_lr variable
    r2 = r2_score(y_test, y_lr)     #  r2_score is used to evaluate the performance of a Linear Regressor
        
    if r2>r2score_maxAccuracy:
        r2score_maxAccuracy=r2
        maxRandomState=i
        

print("------------------------------------------------")
print("                                                ")
print("R2 Score of Linear Regression is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of Linear  Regression in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of Linear  Regression is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("R2 Score of Linear  Regression is Model is Good...")
else:
    print("R2 Score of Linear  Regression is Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")
# Out:
# ------------------------------------------------
#
# R2 Score of Linear Regression is :  0.08181022076413547
#
# R2 Score of Linear  Regression in Percentage is:  8.0 %
#
# R2 Score of Linear  Regression is Bad Model...
#
# Random State 46
#
# ------------------------------------------------

# %% [markdown]
# ### Decision Tree Regressor

# %% [markdown]
# Note :  Decision tree regression observes features of an object and trains a model in the structure of a tree to predict data in the future to produce meaningful continuous output.

# %%
r2score_maxAccuracy = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.30, random_state=i)    # Creating train test split
    dt = DecisionTreeRegressor()    # Creating Object of the Decision Tree Regressor
    dt.fit(X_train, y_train)        # Fitting the x and y train data
    y_dt = dt.predict(X_test)       # predicting the x_test data and storing it into y_dt variable
    r2 = r2_score(y_test, y_dt)     #  r2_score is used to evaluate the performance of a Decision Tree Regressor
    
    
    if r2>r2score_maxAccuracy:      
        r2score_maxAccuracy=r2
        maxRandomState=i
        

print("------------------------------------------------")
print("                                                ")
print("R2 Score of Decision Tree Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of Decision Tree Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of Decision Tree Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")

# %% [markdown]
# ### KNeighbors - Regressor

# %% [markdown]
# Note :

# %%
r2score_maxAccuray = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=i)      # Creating train test split
    knn = KNeighborsRegressor()         # Creating Object of the KNeighbors Regressor
    knn.fit(X_train, y_train)           # Fitting the x and y train data
    y_knn = knn.predict(X_test)         # predicting the x_test data and storing it into y_knn variable
    r2 = r2_score(y_test, y_knn)        #  r2_score is used to evaluate the performance of a KNeighbors Regressor
    
    if r2 > r2score_maxAccuracy:
        r2score_maxAccuracy = r2
        maxRandomState = i



print("------------------------------------------------")
print("                                                ")
print("R2 Score of KNeighbors Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of Decision Tree Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of Decision Tree Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")

# %% [markdown]
# ### SVR (Support Vector Machine - Regressor)

# %% [markdown]
# Note : SVR uses the same basic idea as Support Vector Machine (SVM), a classification algorithm, but applies it to predict real values rather than a class. SVR acknowledges the presence of non-linearity in the data and provides a proficient prediction model.

# %%
r2score_maxAccuray = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=i)      # Creating train test split
    svr = SVR()                         # Creating Object of the SVR (Support Vector Machine) Regressor
    svr.fit(X_train, y_train)           # Fitting the x and y train data
    y_svr = svr.predict(X_test)         # predicting the x_test data and storing it into y_svr variable
    r2 = r2_score(y_test, y_svr)        #  r2_score is used to evaluate the performance of a SVR (Support Vector Machine) Regressor
    
    if r2 > r2score_maxAccuracy:
        r2score_maxAccuracy = r2
        maxRandomState = i



print("------------------------------------------------")
print("                                                ")
print("Best R2 Score of SVR(Support Vector Machine) Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of SVR(Support Vector Machine) Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of SVR(Support Vector Machine) Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")

# %% [markdown]
# ### Random Forest Regression

# %% [markdown]
# Note : The Random Forest is a Regressor algorithm consisting of many decisions trees. It uses bagging and feature randomness when building each individual tree to try to create an uncorrelated forest of trees whose prediction by committee is more accurate than that of any individual tree

# %%
r2score_maxAccuray = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=i)      # Creating train test split
    rf = RandomForestRegressor()                         # Creating Object of the RandomForest Regressor
    rf.fit(X_train, y_train)           # Fitting the x and y train data
    y_rf = rf.predict(X_test)         # predicting the x_test data and storing it into y_rf variable
    r2 = r2_score(y_test, y_rf)        #  r2_score is used to evaluate the performance of a RandomForest Regressor
    
    if r2 > r2score_maxAccuracy:
        r2score_maxAccuracy = r2
        maxRandomState = i



print("------------------------------------------------")
print("                                                ")
print("R2 Score of RandomForest Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of RandomForest Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of RandomForest Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")

# %% [markdown]
# ### Gradient Boost Regressor

# %% [markdown]
# Note :  Gradient Boost Regressor is used to reduce the loss function

# %%
r2score_maxAccuray = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=i)      # Creating train test split
    gb = GradientBoostingRegressor()   # Creating Object of the GradientBoost Regressor
    gb.fit(X_train, y_train)           # Fitting the x and y train data
    y_gb = gb.predict(X_test)          # predicting the x_test data and storing it into y_gb variable
    r2 = r2_score(y_test, y_gb)        # r2_score is used to evaluate the performance of a GradientBoost Regressor
    
    if r2 > r2score_maxAccuracy:
        r2score_maxAccuracy = r2
        maxRandomState = i



print("------------------------------------------------")
print("                                                ")
print("R2 Score of Gradient Boost Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of Gradient Boost Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of Gradient Boost Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")

# %% [markdown]
# ### Ada Boost Regressor

# %% [markdown]
# Note : AdaBoost can be used to boost the performance of any machine learning algorithm

# %%
r2score_maxAccuray = 0
maxRandomState = 0

for i in range(1, 100):
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=i)      # Creating train test split
    ab = AdaBoostRegressor()   # Creating Object of the AdaBoost Regressor
    ab.fit(X_train, y_train)           # Fitting the x and y train data
    y_ab = ab.predict(X_test)          # predicting the x_test data and storing it into y_gb variable
    r2 = r2_score(y_test, y_ab)        # r2_score is used to evaluate the performance of a AdaBoost Regressor
    
    if r2 > r2score_maxAccuracy:
        r2score_maxAccuracy = r2
        maxRandomState = i



print("------------------------------------------------")
print("                                                ")
print("R2 Score of AdaBoost Regressor is : ", r2score_maxAccuracy)
print("                                                ")
r2score_maxAccuracy_percentage = round(r2score_maxAccuracy,2)*100
print("R2 Score of AdaBoost Regressor Regressor in Percentage is: ", r2score_maxAccuracy_percentage,"%")
print("                                                ")
if r2score_maxAccuracy_percentage < 70:
    print("R2 Score of AdaBoost Regressor Regressor is Bad Model...")
elif r2score_maxAccuracy_percentage == 80:
    print("Model is Good...")
else:
    print("Best Model")
print("                                                ")
print("Random State", maxRandomState)
print("                                                ")
print("------------------------------------------------")
